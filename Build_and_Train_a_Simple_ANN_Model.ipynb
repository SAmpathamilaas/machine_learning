# %% [markdown]
# <a href="https://colab.research.google.com/github/SAmpathamilaas/machine_learning/blob/main/Build_and_Train_a_Simple_ANN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense

# %% [markdown]
# Load the data

# %%
df = pd.read_csv('/content/Mobile_Price_Classification-220531-204702.csv')

# %% [markdown]
# Split the data set into training and testing data where it contains 75% of the data as training and rest as testing data

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  ...  three_g  touch_screen  wifi  price_range
# 0            842     0          2.2         0  ...        0             0     1            1
# 1           1021     1          0.5         1  ...        1             1     0            0
# 2            563     1          0.5         1  ...        1             1     0            0
# 3            615     1          2.5         0  ...        1             0     0            0
# 4           1821     1          1.2         0  ...        1             1     0            1
#
# [5 rows x 21 columns]

# %%
x = df.drop('price_range',axis=1)
y = df['price_range']

# %% [markdown]
# 75% traning test ,25% testing set

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.25,random_state=42)

# %% [markdown]
# build the ANN model

# %%
model = Sequential([
    Dense(8, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 2s 15ms/step - loss: 18.5870 - accuracy: 0.5022 - val_loss: 8.0632 - val_accuracy: 0.5800
# Epoch 2/100
# 43/43 [==============================] - 0s 8ms/step - loss: 7.9036 - accuracy: 0.5770 - val_loss: 6.3547 - val_accuracy: 0.6200
# Epoch 3/100
# 43/43 [==============================] - 0s 6ms/step - loss: 6.3992 - accuracy: 0.5874 - val_loss: 5.2121 - val_accuracy: 0.6200
# Epoch 4/100
# 43/43 [==============================] - 0s 4ms/step - loss: 5.2325 - accuracy: 0.5926 - val_loss: 4.2270 - val_accuracy: 0.6133
# Epoch 5/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.2016 - accuracy: 0.5948 - val_loss: 3.4286 - val_accuracy: 0.6133
# Epoch 6/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.1698 - accuracy: 0.5985 - val_loss: 2.6914 - val_accuracy: 0.5800
# Epoch 7/100
# ...

# %%
model.save_weights('ann_model_weights.h5')

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'Test loss: {test_loss}, Test accuracy: {test_accuracy}')
# Out:
# Test loss: 0.5870480537414551, Test accuracy: 0.6380000114440918
